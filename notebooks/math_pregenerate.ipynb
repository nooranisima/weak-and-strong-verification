# %% [markdown]
# # MATH Dataset: Pre-generate Solutions
#
# **Step 1 of 2**: Query LLMs to generate solutions, weak scores, and ground truth labels.
#
# This notebook produces a JSON file that is consumed by `math_experiment.ipynb`.

# %%
# Install dependencies (Colab)
# !pip install openai datasets numpy
# Out:
# Requirement already satisfied: openai in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (2.17.0)
# Requirement already satisfied: datasets in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (4.5.0)
# Requirement already satisfied: numpy in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from openai) (4.15.0)
# Requirement already satisfied: filelock in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (23.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (2.32.2)
# Requirement already satisfied: xxhash in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2024.6.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: idna>=2.8 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: certifi in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.0)
# Requirement already satisfied: typer-slim in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.21.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: click>=8.0.0 in /Users/nooranis/Desktop/FLCP/TinyConftr/.conda/lib/python3.11/site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.1.7)

# %%
import sys
sys.path.insert(0, '..')  # Add repo root to path

import numpy as np
from src.config import make_experiment_config
from src.llm import LLMWrapper
from src.data.math_dataset import sample_and_save_datasets
from src.data.pregeneration import pregenerate_all_data, append_pregenerated_data, print_pregeneration_stats

# %% [markdown]
# ## Configuration

# %%
# API Keys
OPENAI_API_KEY = ""  # or set OPENAI_API_KEY env var
DEEPSEEK_API_KEY = ""  # or set DEEPSEEK_API_KEY env var

# Experiment settings
RANDOM_SEED = 42
EXAMPLES_PER_DIFFICULTY = 200
DIFFICULTY_LEVELS = [2, 3, 5]
NUM_ATTEMPTS = 5

RESULTS_DIR = "../results"

# Create config
config = make_experiment_config(
    openai_api_key=OPENAI_API_KEY,
    deepseek_api_key=DEEPSEEK_API_KEY,
    use_deepseek_weak_verifier=True,
    use_math_shepherd=False,
    generator_model="gpt-4o-mini",
    strong_verifier_model="gpt-4o-mini",
)

llm = LLMWrapper(config)
print(f"Weak verifier: {type(llm.weak_verifier).__name__}")
# Out:
# Weak verifier: DeepSeekWeakVerifier

# %% [markdown]
# ## Load Dataset

# %%
np.random.seed(RANDOM_SEED)

datasets = sample_and_save_datasets(
    seed=RANDOM_SEED,
    examples_per_difficulty=EXAMPLES_PER_DIFFICULTY,
    difficulty_levels=DIFFICULTY_LEVELS,
)

for diff, probs in datasets.items():
    print(f"  Difficulty {diff}: {len(probs)} problems")
# Out:
# Loading MATH dataset (levels [2])...
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/5.12M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/210k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/12000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/500 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/12000 [00:00<?, ? examples/s]
# ✓ Loaded 200 problems (levels [2])
# Loading MATH dataset (levels [3])...
# Filter:   0%|          | 0/12000 [00:00<?, ? examples/s]
# ✓ Loaded 200 problems (levels [3])
# Loading MATH dataset (levels [5])...
# Filter:   0%|          | 0/12000 [00:00<?, ? examples/s]
# ✓ Loaded 200 problems (levels [5])
#   Difficulty 2: 200 problems
#   Difficulty 3: 200 problems
#   Difficulty 5: 200 problems

# %% [markdown]
# ## Pre-generate Solutions

# %%
pregenerated_data = pregenerate_all_data(
    datasets=datasets,
    llm=llm,
    num_problems=1, #EXAMPLES_PER_DIFFICULTY,
    num_attempts=NUM_ATTEMPTS,
    difficulties=DIFFICULTY_LEVELS,
    save_dir=RESULTS_DIR,
    checkpoint_freq=10,
    random_seed=RANDOM_SEED,
)
# Out:
# ============================================================
# DIFFICULTY 2
# ============================================================
#   Problem 1/1 | Correct: 5/5 | Avg weak: 0.996 | Rate: 0.1 attempts/sec
#     → Checkpoint saved
#
# ============================================================
# DIFFICULTY 3
# ============================================================
#   Problem 1/1 | Correct: 5/5 | Avg weak: 0.994 | Rate: 0.2 attempts/sec
#     → Checkpoint saved
#
# ============================================================
# DIFFICULTY 5
# ============================================================
#   Problem 1/1 | Correct: 0/5 | Avg weak: 0.248 | Rate: 0.1 attempts/sec
#     → Checkpoint saved
#
# ============================================================
# PRE-GENERATION COMPLETE
# ============================================================
# Total problems: 3
# Total attempts: 15
# Time: 122.8s (0.1 attempts/sec)
#
# --- Summary Statistics ---
#
# Difficulty 2:
#   Problems: 1
#   Total attempts: 5
#   Overall accuracy: 100.0%
#   Problems solvable (≥1 correct): 1/1 (100.0%)
#   Weak score - mean: 0.996, std: 0.005
#
# Difficulty 3:
#   Problems: 1
#   Total attempts: 5
#   Overall accuracy: 100.0%
#   Problems solvable (≥1 correct): 1/1 (100.0%)
#   Weak score - mean: 0.994, std: 0.008
#
# Difficulty 5:
#   Problems: 1
#   Total attempts: 5
#   Overall accuracy: 0.0%
#   Problems solvable (≥1 correct): 0/1 (0.0%)
#   Weak score - mean: 0.248, std: 0.015
#
# ✓ Final data saved to: ../results/pregenerated_20260206_151818.json
# ✓ Checkpoint cleaned up

# %% [markdown]
# ## (Optional) Append More Data

# %%
# Uncomment to append more problems to an existing file:
#
# pregenerated_data = append_pregenerated_data(
#     existing_path="../results/pregenerated_XXXXXXXX_XXXXXX.json",
#     datasets=datasets,
#     llm=llm,
#     num_additional_problems=50,
#     num_attempts=NUM_ATTEMPTS,
#     difficulties=DIFFICULTY_LEVELS,
# )
